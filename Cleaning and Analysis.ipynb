# %%
import pandas as pd
import numpy as np
import os, random, math, glob
from IPython.display import Image as IM
from IPython.display import clear_output
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [16, 10]

# %%
tr = pd.read_csv('Train.csv')
tr.head()
# Out:
#                ward  total_households  ...        lon        NL
# 0  41601001: Ward 1        1674.45058  ...  24.734743  0.292039
# 1  41601002: Ward 2        1736.99230  ...  24.757737  3.207775
# 2  41601003: Ward 3        2403.57591  ...  25.094093  0.000000
# 3  41601004: Ward 4        1740.78737  ...  24.942867  2.038778
# 4  41601005: Ward 5        1730.51451  ...  25.290165  0.000000
#
# [5 rows x 63 columns]

# %%
ts = pd.read_csv('Test.csv')
ts.head()
# Out:
#                ward  total_households  ...        lon        NL
# 0  21001001: Ward 1        2504.95194  ...  23.848688  0.000000
# 1  21001002: Ward 2        2080.27718  ...  24.555818  0.000000
# 2  21001003: Ward 3        1106.62639  ...  24.563940  8.269556
# 3  21001004: Ward 4        2175.56096  ...  24.542202  8.626625
# 4  21001005: Ward 5        1270.83883  ...  24.558537  8.601754
#
# [5 rows x 62 columns]

# %%
var_desc = pd.read_csv('variable_descriptions.csv')
pd.set_option('display.max_colwidth', 200) # So that we can see the full descriptions
var_desc
# Out:
#         Column  ...                                              Unnamed: 3
# 0        dw_00  ...                                                     NaN
# 1        dw_01  ...                                                     NaN
# 2        dw_02  ...                                                     NaN
# 3        dw_03  ...                                                     NaN
# 4        dw_04  ...                                                     NaN
# 5        dw_05  ...                                                     NaN
# 6        dw_06  ...                                                     NaN
# 7        dw_07  ...                                                     NaN
# 8        dw_08  ...   e.g. in an informal/squatter settlement or on a farm)
# 9        dw_09  ...                                                     NaN
# 10       dw_10  ...                                                     NaN
# 11       dw_11  ...                                                     NaN
# 12       dw_12  ...                                                     NaN
# 13       dw_13  ...                                                     NaN
# 14      psa_00  ...                                                     NaN
# 15      psa_01  ...                                                     NaN
# 16      psa_02  ...                                                     NaN
# 17      psa_03  ...                                                     NaN
# 18      psa_04  ...                                                     NaN
# 19      stv_00  ...                                                     NaN
# 20      stv_01  ...                                                     NaN
# 21      car_00  ...                                                     NaN
# 22      car_01  ...                                                     NaN
# 23      lln_00  ...                                                     NaN
# 24      lln_01  ...                                                     NaN
# 25      lan_00  ...                                                     NaN
# 26      lan_01  ...                                                     NaN
# 27      lan_02  ...                                                     NaN
# 28      lan_03  ...                                                     NaN
# 29      lan_04  ...                                                     NaN
# 30      lan_05  ...                                                     NaN
# 31      lan_06  ...                                                     NaN
# 32      lan_07  ...                                                     NaN
# 33      lan_08  ...                                                     NaN
# 34      lan_09  ...                                                     NaN
# 35      lan_10  ...                                                     NaN
# 36      lan_11  ...                                                     NaN
# 37      lan_12  ...                                                     NaN
# 38      lan_13  ...                                                     NaN
# 39      lan_14  ...                                                     NaN
# 40       pg_00  ...                                                     NaN
# 41       pg_01  ...                                                     NaN
# 42       pg_02  ...                                                     NaN
# 43       pg_03  ...                                                     NaN
# 44       pg_04  ...                                                     NaN
# 45      lgt_00  ...                                                     NaN
# 46       pw_00  ...                                                     NaN
# 47       pw_01  ...                                                     NaN
# 48       pw_02  ...                                                     NaN
# 49       pw_03  ...                                                     NaN
# 50       pw_04  ...                                                     NaN
# 51       pw_05  ...                                                     NaN
# 52       pw_06  ...                                                     NaN
# 53       pw_07  ...                                                     NaN
# 54       pw_08  ...                                                     NaN
# 55  ADM4_PCODE  ...                                                     NaN
# 56         lat  ...                                                     NaN
# 57         lon  ...                                                     NaN
# 58          NL  ...                                                     NaN
# 59      target  ...                                                     NaN
#
# [60 rows x 4 columns]

# %%
ss = pd.read_csv('SampleSubmission.csv')
ss.head()
# Out:
#                ward  target
# 0  21001001: Ward 1   21.87
# 1  21001002: Ward 2   65.94
# 2  21001003: Ward 3   83.65
# 3  21001004: Ward 4     NaN
# 4  21001005: Ward 5     NaN

# %% [markdown]
# # Data Cleaning:

# %%
tr.shape
# Out:
# (2822, 63)

# %%
ts.shape
# Out:
# (1013, 62)

# %% [markdown]
# Missing values and datatype per column::

# %%
tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2822 entries, 0 to 2821
# Data columns (total 63 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ward               2822 non-null   object
#  1   total_households   2822 non-null   float64
#  2   total_individuals  2822 non-null   float64
#  3   target             2822 non-null   float64
#  4   dw_00              2822 non-null   float64
#  5   dw_01              2822 non-null   float64
#  6   dw_02              2822 non-null   float64
#  7   dw_03              2822 non-null   float64
#  8   dw_04              2822 non-null   float64
#  9   dw_05              2822 non-null   float64
#  10  dw_06              2822 non-null   float64
#  11  dw_07              2822 non-null   float64
#  12  dw_08              2822 non-null   float64
#  13  dw_09              2822 non-null   float64
#  14  dw_10              2822 non-null   float64
#  15  dw_11              2822 non-null   float64
#  16  dw_12              2822 non-null   int64
#  17  dw_13              2822 non-null   int64
#  18  psa_00             2822 non-null   float64
#  19  psa_01             2822 non-null   float64
#  20  psa_02             2822 non-null   float64
#  21  psa_03             2822 non-null   float64
#  22  psa_04             2822 non-null   float64
#  23  stv_00             2822 non-null   float64
#  24  stv_01             2822 non-null   float64
#  25  car_00             2822 non-null   float64
#  26  car_01             2822 non-null   float64
#  27  lln_00             2822 non-null   float64
#  28  lln_01             2822 non-null   float64
#  29  lan_00             2822 non-null   float64
#  30  lan_01             2822 non-null   float64
#  31  lan_02             2822 non-null   float64
#  32  lan_03             2822 non-null   float64
#  33  lan_04             2822 non-null   float64
#  34  lan_05             2822 non-null   float64
#  35  lan_06             2822 non-null   float64
#  36  lan_07             2822 non-null   float64
#  37  lan_08             2822 non-null   float64
#  38  lan_09             2822 non-null   float64
#  39  lan_10             2822 non-null   float64
#  40  lan_11             2822 non-null   float64
#  41  lan_12             2822 non-null   float64
#  42  lan_13             2822 non-null   int64
#  43  lan_14             2822 non-null   float64
#  44  pg_00              2822 non-null   float64
#  45  pg_01              2822 non-null   float64
#  46  pg_02              2822 non-null   float64
#  47  pg_03              2822 non-null   float64
#  48  pg_04              2822 non-null   float64
#  49  lgt_00             2822 non-null   float64
#  50  pw_00              2822 non-null   float64
#  51  pw_01              2822 non-null   float64
# Duplicates::

# %%
tr.duplicated().any()
# Out:
# False

# %%
ts.duplicated().any()
# Out:
# False

# %%
new_list = tr.columns[:31]

# %%
next_list = tr.columns[31:]

# %%
atr = tr.drop(new_list, axis=1)
btr = tr.drop(next_list, axis=1)

# %%
atr.shape
# Out:
# (2822, 32)

# %%
btr.shape
# Out:
# (2822, 31)

# %%
# Plot histogram of numeric variables in dataset
atr.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d29d7d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d2a52750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d296ae50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d299a390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d293d890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d28e8d90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d28a9350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d28df790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d28df7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d2897dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d280f710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d27c5c10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d2788150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d2740650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d26f6b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d26a3b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d2672590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d2627a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d265ef90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d25a04d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d25d89d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d258eed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d2550410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d2507910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d24bde10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d2482350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d2437850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d23edd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d23b1290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d2368790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d239fc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d22e31d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d231a6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d22d0bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d2294110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d2248610>]],
#       dtype=object)

# %%
# Plot histogram of numeric variables in dataset
btr.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d1bd0650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d1b78f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d1aef650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d1b0ab50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d1aaab90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d1a74590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d1a28b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d1a5ff90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d19ed050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d19a25d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d198fed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d1952410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d1908910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d18bfe10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d1883350>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d183a850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d17f0d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d17b5290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d1770710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d1727bd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d16ea110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d16a1610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d16d8b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d1690fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d164d5d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d1601ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d15adb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d157c510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d1532a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d14e9f10>]],
#       dtype=object)

# %% [markdown]
# ## Looking at the target variable
# The purpose of this competition is to predict the percentage of households in a ward that are woman-headed and have an annual household income of <R19,600. To put that in context, that's less than 250USD per month.

# %%
# Plot the distribution
ax = df['target'].plot(kind='hist')
plt.xlabel('Percentage of households that are w-headed and have income under R19.6k/month')
# Out:
# Text(0.5, 0, 'Percentage of households that are w-headed and have income under R19.6k/month')

# %% [markdown]
# # Looking at a few interesting correlations

# %%
# Strong +ve correlations
df.corr()['target'].sort_values(ascending=False).head(10)
# Out:
# target    1.000000
# psa_00    0.782472
# car_01    0.702831
# stv_01    0.664181
# lln_01    0.637835
# pg_00     0.613346
# pw_06     0.470676
# dw_01     0.458206
# pw_02     0.442441
# pw_03     0.440941
# Name: target, dtype: float64

# %%
# And negative correlations
df.corr()['target'].sort_values().head(10)
# Out:
# pw_00    -0.754536
# psa_01   -0.707506
# car_00   -0.702831
# stv_00   -0.664181
# lln_00   -0.637835
# pg_03    -0.583908
# NL       -0.514398
# lan_00   -0.507942
# lan_01   -0.438704
# dw_04    -0.385533
# Name: target, dtype: float64

# %% [markdown]
# There are some high correlations here. Let's pick a few and investigate.

# %%
# pw_00: running water in the home. Places where almost everyone has piped water tend to be more affluent.
df.plot(x='pw_00', y='target', kind='scatter', alpha=0.3)

# %%
# Nightlights (NL)
df.plot(x='NL', y='target', kind='scatter', alpha=0.3)

# %%
# dw_01: Percentage of dwellings of type: Traditional dwelling/hut/structure made of traditional materials
# Places where many of the buildings are 'traditional' tend to have more households 
# in the target category. 
df.plot(x='dw_01', y='target', kind='scatter', alpha=0.3)

# %% [markdown]
# Notice that for the dwelling type example above, the left hand side of the graph is chaotic. Fitting a straight line would tell part of the story, but to fully capture the trend we'd have to look at this data in conjunction with info on all the other dwelling types, and think about how trends might be different in rural vs urban areas.
